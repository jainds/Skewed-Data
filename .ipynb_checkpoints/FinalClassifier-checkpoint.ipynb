# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import numpy
import pandas
import math

data = pandas.read_csv('ClassificationProblem1.txt', sep="\t")
data = data.set_index("Index", drop =True)
data.head()
# Out:
#              F1        F2        F3        F4    F5    F6    F7    F8    F9  \
# Index
# 1      0.224506  0.500340  0.489860  0.902413  7934 -6970 -5714  9982 -5697
# 2      0.321128  0.281119  0.907283  0.772159 -8238  1219  1663  1287 -3658
# 3      0.893441  0.622005  0.998776  0.098386  8540  5266 -9377 -3504 -4511
# 4      0.320641  0.957234  0.346000  0.646479 -7772  -383  9681 -8661  3474
# 5      0.475961  0.623008  0.544988  0.159709  1571 -8039 -7961 -2385  4407
#
#               F10 ...         F14        F15         F16  F17 F18  F19  F20  \
# Index             ...
# 1      4227810299 ... -3433637453  10/4/1986    9/6/1992    2   1  706  305
# 2     -1146724819 ...   609277486  2/24/1979    1/5/1983    1   1  423  206
# 3      5947184989 ... -8977995005  1/12/1989  11/22/1986    2   1  703  315
# 4     -5724795826 ...  4868760308  2/18/1982   6/10/1992    1   1  122  304
# 5     -3097637172 ...  9757408267  4/10/1987  10/19/1985    1   1  486  240
#
#        F21  F22  C
# ...

# %%
data.describe()
data['F15'] = pandas.to_datetime(data['F15'], errors='raise', dayfirst=False, yearfirst=False, utc=None, box=True, format="%m/%d/%Y", exact=True, unit=None, infer_datetime_format=False)
data['F16'] = pandas.to_datetime(data['F16'], errors='raise', dayfirst=False, yearfirst=False, utc=None, box=True, format="%m/%d/%Y", exact=True, unit=None, infer_datetime_format=False)

# %%
data.describe()
# Out:
#                  F1            F2            F3            F4            F5  \
# count  19913.000000  19913.000000  19913.000000  19913.000000  19913.000000
# mean       0.499991      0.500893      0.499128      0.499067     15.011952
# std        0.287076      0.288236      0.289164      0.288076   5779.233483
# min        0.000041      0.000013      0.000153      0.000044 -10000.000000
# 25%        0.251199      0.251930      0.247825      0.249564  -5006.000000
# 50%        0.499419      0.499680      0.497751      0.498086     32.000000
# 75%        0.749192      0.752245      0.750036      0.749481   5014.000000
# max        0.999993      0.999992      0.999949      0.999845  10000.000000
#
#                  F6            F7            F8            F9           F10  \
# count  19913.000000  19913.000000  19913.000000  19913.000000  1.991300e+04
# mean     -71.673932      2.344348     11.675689     60.423693 -2.642097e+07
# ...

# %%
data1 = data.drop(data.columns[[14,15]], axis=1, inplace=False)
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19913 entries, T30234341 to T30254253
# Data columns (total 20 columns):
# F1     19913 non-null float64
# F2     19913 non-null float64
# F3     19913 non-null float64
# F4     19913 non-null float64
# F5     19913 non-null int64
# F6     19913 non-null int64
# F7     19913 non-null int64
# F8     19913 non-null int64
# F9     19913 non-null int64
# F10    19913 non-null int64
# F11    19913 non-null int64
# F12    19913 non-null int64
# F13    19913 non-null int64
# F14    19913 non-null int64
# F17    19913 non-null int64
# F18    19913 non-null int64
# F19    19913 non-null int64
# F20    19913 non-null int64
# F21    19913 non-null int64
# F22    19913 non-null int64
# dtypes: float64(4), int64(16)
# memory usage: 3.1+ MB

# %%
core = data.corr(method='pearson')
print core
# Out:
#            F1        F2        F3        F4        F5        F6        F7  \
# F1   1.000000 -0.011363  0.011149  0.017201  0.007114  0.001198  0.007269
# F2  -0.011363  1.000000  0.005321 -0.000034  0.000976  0.005540 -0.013603
# F3   0.011149  0.005321  1.000000 -0.005301 -0.011889  0.001125  0.001267
# F4   0.017201 -0.000034 -0.005301  1.000000 -0.002561  0.012192 -0.002842
# F5   0.007114  0.000976 -0.011889 -0.002561  1.000000  0.000463 -0.001299
# F6   0.001198  0.005540  0.001125  0.012192  0.000463  1.000000  0.002037
# F7   0.007269 -0.013603  0.001267 -0.002842 -0.001299  0.002037  1.000000
# F8  -0.000521  0.001803 -0.005011  0.012477  0.005595  0.003410  0.006238
# F9   0.001471 -0.012878 -0.001866 -0.003043  0.012254 -0.001274  0.002220
# F10 -0.001693 -0.005820 -0.008852  0.001765 -0.006428  0.016284 -0.006959
# F11  0.010525 -0.007471  0.006254  0.007849 -0.000098  0.002289  0.007651
# F12  0.001224  0.002528 -0.004862  0.016415  0.004125 -0.003521 -0.013102
# ...

# %%
_num_size = core.shape
f, ax = plt.subplots(figsize=_num_size)
sns.heatmap(core, vmax=0.1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
new_data= data.drop(data.columns[[16,17,18,19]], axis=1)
new_data.describe()
new_core = new_data.corr(method='pearson')

# %%
_num_size = new_core.shape
f, ax = plt.subplots(figsize=_num_size)
sns.heatmap(new_core, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
# ...

# %%
sns.set(style="darkgrid")
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data, annot=True, ax=ax)
f.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-0b7697cb2756> in <module>()
#       1 sns.set(style="darkgrid")
#       2 f, ax = plt.subplots(figsize=(10, 10))
# ----> 3 sns.heatmap(data1, annot=True, ax=ax)
#       4 f.tight_layout()
#
# C:\ProgramData\Anaconda2\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, ax, xticklabels, yticklabels, mask, **kwargs)
#     494     if square:
#     495         ax.set_aspect("equal")
# --> 496     plotter.plot(ax, cbar_ax, kwargs)
#     497     return ax
#     498
#
# C:\ProgramData\Anaconda2\lib\site-packages\seaborn\matrix.py in plot(self, ax, cax, kws)
#     272         if axis_ticklabels_overlap(xtl):
#     273             plt.setp(xtl, rotation="vertical")
# ...

# %%
sns.set(style="ticks")
sns.pairplot(data, hue="C")
